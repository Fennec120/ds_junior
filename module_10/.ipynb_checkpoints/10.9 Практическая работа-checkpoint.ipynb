# %% [markdown]
# ## Цели практической работы
#
# * Изучить и предобработать данные в задаче оттока.
#
# * Научиться применять для решения задачи решающие деревья и оценивать результаты модели.

# %% [markdown]
# ## Что входит в практическую работу
#
# *  Загрузка и предобработка данных.
# *  Применение и настройка линейных моделей.
# *  Применение и настройка решающего дерева.
# *  Сравнение моделей.
# *  Оценка важности признаков.

# %% [markdown]
# ## Что оценивается
#
# Выполнены все задания ноутбука (заполнены пустые ячейки, даны ответы на вопросы).

# %% [markdown]
# ## Что нужно сделать
# Решите задачу классификации оттоковых клиентов телекома: для каждого клиента необходимо определить, перестанет он пользоваться услугами оператора в ближайшее время или нет.

# %%
import pylab as plt
# import matplotlib as plt

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("telecom_churn.csv")

cols = list(df.columns)
cols
for col in range(len(cols)):
    cols[col] = cols[col].lower()

    
cols_dict = dict()
for col in range(len(df.columns)):
    cols_dict[df.columns[col]] = cols[col]
    

    

df = df.rename(columns=cols_dict)


df.head()
# Out:
#   state  account length  area code international plan voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    number vmail messages  total day minutes  total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    total day charge  total eve minutes  total eve calls  total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    customer service calls  churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %% [markdown]
# Сделайте первичную обработку данных:
#
# 1. Выбросите колонку State.
#
# 2. Колонки International plan и Voice mail plan закодируйте следующим образом: Yes замените на 1, а No на 0.
#
# 3. Переведите целевую переменную (Churn) в числа: True в 1, а False в 0.

# %%
# ваш код здесь
df = df.drop('state', axis=1)
df['voice mail plan'] = df['voice mail plan'].apply(lambda x: 0 if x == 'No' else 1)
df['international plan'] = df['international plan'].apply(lambda x: 0 if x == 'No' else 1)
# ваш код здесь
df['churn'] = df['churn'].astype(int)

# %% [markdown]
# Выведите на экран первые строки изменённой таблицы, чтобы проверить, что все преобразования сработали.

# %%
df.head()
# Out:
#    account length  area code  international plan  voice mail plan  \
# 0             128        415                   0                1
# 1             107        415                   0                1
# 2             137        415                   0                0
# 3              84        408                   1                0
# 4              75        415                   1                0
#
#    number vmail messages  total day minutes  total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    total day charge  total eve minutes  total eve calls  total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    customer service calls  churn
# 0                       1      0
# 1                       1      0
# 2                       0      0
# 3                       2      0
# 4                       3      0

# %%
from sklearn.preprocessing import StandardScaler


cols_to_scale = []
for col in df.columns:
    counts = df[col].value_counts()
    if list(counts.keys()) == [0,1] or list(counts.keys()) == [1,0]:
        continue
    cols_to_scale.append(col)

# %%
#скалируем
def scaler_default(df2):
    cols_to_scale = []


    cols_obj = []
    for col in df2.columns:
        if col == 'target':
            continue
        if '_' in col:
            continue
        if df2[col].dtype != 'object':
            cols_to_scale.append(col)
    col_names = cols_to_scale.copy()

    for i in range(len(col_names)):
        col_names[i] = col_names[i] + '_scaled'

    scaler2 = StandardScaler()
    df_scaled = scaler2.fit_transform(df2[cols_to_scale])
    df2[col_names] = pd.DataFrame.from_records(df_scaled, columns=col_names)
    df2 = df2.drop(cols_to_scale, axis=1)
    return df2

# %%
#скалируем
def scaler(df2, cols_to_scale):
    
   
    col_names = cols_to_scale.copy()

    for i in range(len(col_names)):
        col_names[i] = col_names[i] + '_scaled'

    scaler2 = StandardScaler()
    df_scaled = scaler2.fit_transform(df2[cols_to_scale])
    df2[col_names] = pd.DataFrame.from_records(df_scaled, columns=col_names)
    df2 = df2.drop(cols_to_scale, axis=1)
    return df2

# %%
df = scaler(df, cols_to_scale)

# %% [markdown]
# Создайте матрицу объект-признак X и вектор с целевой переменной (Churn) y.

# %%
# ваш код здесь
x = df.drop('churn', axis=1)
y = df.churn

# %% [markdown]
# Проверьте баланс классов. Является ли выборка сбалансированной?

# %%
# ваш код здесь
y.value_counts()
# Out:
# churn
# 0    2850
# 1     483
# Name: count, dtype: int64

# %%
plt.figure(figsize=(2,1))
plt.hist(df.churn)
plt.title('n / Y')
plt.show()

# %% [markdown]
# Разбейте данные на тренировочную и тестовую части, размер тестовой части — 30%.

# %%
from sklearn.model_selection import train_test_split

# ваш код здесь
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state=42)

# %% [markdown]
# Для линейных моделей очень важно масштабирование признаков. Поэтому отмасштабируйте признаки при помощи [StandardScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html), обучив метод на тренировочных данных и применив его и к трейну, и к тесту.

# %%
# done before x/y split

# %% [markdown]
# После масштабирования признаков X_train и X_test перестали быть объектами типа pd.DataFrame, это неудобно. Приведите их снова к pd.DataFrame.

# %%
# - - -- - -- - --

# %%
# ваш код здесь

# %% [markdown]
# Обучите на тренировочных данных с параметрами по умолчанию:
#
# 1) логистическую регрессию;
#
# 2) метод опорных векторов (с kernel='linear').

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.svm import SVR

import warnings
warnings.filterwarnings('ignore')

# %%
logr = LogisticRegression()
svc = SVC(kernel='linear', probability=True)
# svr = SVR(kernel='linear')

models = [
    logr,
    svc,
#     svr,
]

for model in models:
    model.fit(x_train, y_train)

# %% [markdown]
# С помощью обученных моделей сделайте предсказание на тестовых данных. Вычислите значение метрики roc-auc на тесте.
#
# Не забудьте, что для корректного вычисления roc-auc необходимо предсказывать не сами классы, а их вероятности (чтобы SVC мог это сделать, при объявлении модели поставьте probability=True).

# %%
from sklearn.metrics import roc_auc_score

# %%
preds = dict()
scores = dict()
for model in models:
    preds[model] = model.predict_proba(x_test)[ : , 1 ]
    scores[str(model)] = roc_auc_score(y_test, preds[model])
scores
# preds

# ваш код здесь
# Out:
# {'LogisticRegression()': 0.8277125441652863,
#  "SVC(kernel='linear', probability=True)": 0.7557343473329472}

# %% [markdown]
# Теперь обучите решающее дерево с параметрами по умолчанию на тренировочных данных, сделайте предсказание на тесте и вычислите на тесте roc-auc.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree = DecisionTreeClassifier()
tree.fit(x_train, y_train)
preds = tree.predict_proba(x_test)[:,1]
scores[str(tree)] = roc_auc_score(y_test, preds)
scores

# ваш код здесь
# Out:
# {'LogisticRegression()': 0.8277125441652863,
#  "SVC(kernel='linear', probability=True)": 0.7557343473329472,
#  'DecisionTreeClassifier()': 0.8432081337565586}

# %% [markdown]
# Нужно ли масшабировать признаки для обучения решающего дерева? Проверьте это, заново разбив данные на тренировочную и тестовую части (назовите новые полученные объекты новыми названиями), и проведите обучение, предсказание и оценку метрики до масштабирования и после.

# %%
df2 = pd.read_csv("telecom_churn.csv")

cols = list(df2.columns)
cols
for col in range(len(cols)):
    cols[col] = cols[col].lower()

    
cols_dict = dict()
for col in range(len(df2.columns)):
    cols_dict[df2.columns[col]] = cols[col]
        

df2 = df2.rename(columns=cols_dict)
df2 = df2.drop('state', axis=1)
df2['voice mail plan'] = df2['voice mail plan'].apply(lambda x: 0 if x == 'No' else 1)
df2['international plan'] = df2['international plan'].apply(lambda x: 0 if x == 'No' else 1)
# ваш код здесь
df2['churn'] = df2['churn'].astype(int)
x2 = df2.drop('churn', axis=1)
y2 = df2.churn
x_train_unscaled, x_test_unscaled, y_train_unscaled, y_test_unscaled = train_test_split(x2,y2,test_size=0.3, random_state=42)

# %%
usncaled_tree = DecisionTreeClassifier()
usncaled_tree.fit(x_train_unscaled, y_train_unscaled)
preds = usncaled_tree.predict_proba(x_test_unscaled)[:,1]
scores['unscaled_'+str(usncaled_tree)] = roc_auc_score(y_test_unscaled, preds)
scores

# ваш код здесь
# Out:
# {'LogisticRegression()': 0.8277125441652863,
#  "SVC(kernel='linear', probability=True)": 0.7557343473329472,
#  'DecisionTreeClassifier()': 0.8432081337565586,
#  'unscaled_DecisionTreeClassifier()': 0.8379613385447691}

# %% [markdown]
# Какой вывод про масштабирование признаков для обучения дерева можно сделать?

# %%
# практически нет, влияние минимально

# %% [markdown]
# Теперь ваша цель — максимально улучшить модели. Для этого:
#
# 1) у линейных моделей подберите гиперпараметр С (переберите 20 значений C в диапазоне от 0.1 до 10 с равным шагом);
#
# 2) у решающего дерева подберите max_depth (переберите глубину от 1 до 10 с шагом 1) и criterion — gini или entropy (см. [документацию](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html)).
#
# Для подбора параметров используйте [GridSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html) с пятью фолдами и метрикой roc-auc или обычные циклы.
#
# Подбор параметров осуществляется только по тренировочным данным!

# %% [markdown]
# После подбора гиперпараметров обучите модели с найденными гиперпараметрами на тренировочных данных, сделайте предсказания на тесте и оцените их качество (roc_auc).

# %%
models.append(tree)

# %%
models
# Out:
# [LogisticRegression(),
#  SVC(kernel='linear', probability=True),
#  DecisionTreeClassifier()]

# %%
from sklearn.model_selection import GridSearchCV

best_params = dict()
params = {str(models[2]):
          { 
    'max_depth' : np.arange(1, 11, 1),
    'criterion': ['gini', 'entropy'],
            },
          
          str(models[1]):
          {
             'C' : np.arange(0.1, 10, 0.5),
          },
          
          str(models[0]):
          {
             'C' : np.arange(0.1, 10, 0.5),
          }
}

for model in models:
    
    gs = GridSearchCV(model, params[str(model)], cv=5, scoring='roc_auc')
    gs.fit(x_train, y_train)
    print('current model:', model)
    print('best score:', gs.best_score_)
    best_params[str(model)] = gs.best_params_
    print('best params:', best_params[str(model)])
    
# ваш код здесь
# Out:
# current model: LogisticRegression()
# best score: 0.80263089366929
# best params: {'C': 9.1}
# current model: SVC(kernel='linear', probability=True)
# best score: 0.7625459228917698
# best params: {'C': 0.1}
# current model: DecisionTreeClassifier()
# best score: 0.8759538330010661
# best params: {'criterion': 'gini', 'max_depth': 5}

# %%
logr_tuned = LogisticRegression(C= 9.1)
svc_tuned = SVC(kernel='linear', probability=True, C=0.1)
tree_tuned = DecisionTreeClassifier(criterion='gini', max_depth=5)

models_new = [
    logr_tuned,
    svc_tuned,
    tree_tuned,
]

for model in models_new:
    model.fit(x_train, y_train)
    
for model in models_new:
    models.append(model)

# %%
preds = dict()
for model in models:
    preds[str(model)] = model.predict_proba(x_test)[ : , 1 ]
    scores[str(model)] = roc_auc_score(y_test, preds[str(model)])
scores
# Out:
# {'LogisticRegression()': 0.8277125441652863,
#  "SVC(kernel='linear', probability=True)": 0.7557343473329472,
#  'DecisionTreeClassifier()': 0.8432081337565586,
#  'unscaled_DecisionTreeClassifier()': 0.8379613385447691,
#  'LogisticRegression(C=9.1)': 0.8283571737480723,
#  "SVC(C=0.1, kernel='linear', probability=True)": 0.7789818116539237,
#  'DecisionTreeClassifier(max_depth=5)': 0.9075364542108999}

# %% [markdown]
# Какая модель справилась с решением задачи лучше всего по метрике roc-auc?

# %% [markdown]
# Нарисуйте roc-кривую для наилучшей модели.

# %%
first = None
second = None
for key in scores.keys():
    if scores[key] == sorted(scores.values())[-1]:
        first = key
    if scores[key] == sorted(scores.values())[-2]:
        second = key

# %%
from sklearn.metrics import roc_curve
from matplotlib import pyplot as plt
legend = []
plt.figure(figsize=(3,3))
for model in models:
    if first == str(model) or first == 'unscaled_'+str(model) :
#         preds_plot = model.predict_proba(x_test)[ : , 1 ]
#         scores[str(model)] = roc_auc_score(y_test, preds[str(model)])

        fpr, tpr, _ = roc_curve(y_test, preds[str(model)])
        plt.plot(fpr, tpr, '-')
        plt.xlabel('fpr')
        plt.ylabel('tpr')
        legend.append(first)
        
    if second == str(model) or second == 'unscaled_'+str(model) :
#         preds_plot = model.predict_proba(x_test)[ : , 1 ]
#         scores[str(model)] = roc_auc_score(y_test, preds[str(model)])

        fpr, tpr, _ = roc_curve(y_test, preds[str(model)])
        plt.plot(fpr, tpr, '-')
        plt.xlabel('fpr')
        plt.ylabel('tpr')
        legend.append(second)

plt.legend(legend, loc=(1,0))

# %% [markdown]
# Сравните между собой две лучшие модели:
#
# 1. Насколько сильно отличается качество предсказания на тестовых данных?
# (Вычислите разность значений roc-auc.)
#
# 2. Постройте гистограммы важности признаков (для линейных моделей берите модуль значений весов) для каждой из этих моделей. Сравните между собой списки из трёх самых важных признаков. Совпадают ли они?

# %%
# ваш код здесь
round(scores[first] - scores[second], 3)
# Out:
# 0.064

# %%
# разница в 7 % между деревом с тюнингом и дефолтным деревом - на мой взгляд результат очень даже неплохой, 
# особенно когда это происходит так близко к левому верхнему углу графика

# %%
# ваш код здесь
features = x_train.columns
feature_imps = dict()
for model in models:
    try:
        feature_imps[str(model)] = model.feature_importances_
       
    except AttributeError:
        feature_imps[str(model)] = model.coef_[0]

# %%
tst = list(x_train.columns)

feature_imps_df = pd.DataFrame(columns=tst)

# %%
for model in feature_imps.keys():
    feature_imps_df.loc[model] = feature_imps[model]
feature_imps_df
# Out:
#                                                international plan  \
# LogisticRegression()                                     2.092892
# SVC(kernel='linear', probability=True)                   0.000330
# DecisionTreeClassifier()                                 0.078055
# LogisticRegression(C=9.1)                                2.155780
# SVC(C=0.1, kernel='linear', probability=True)            0.000445
# DecisionTreeClassifier(max_depth=5)                      0.117369
#
#                                                voice mail plan  \
# LogisticRegression()                                 -1.084586
# SVC(kernel='linear', probability=True)               -0.000688
# DecisionTreeClassifier()                              0.039908
# LogisticRegression(C=9.1)                            -1.515812
# SVC(C=0.1, kernel='linear', probability=True)        -0.000681
# DecisionTreeClassifier(max_depth=5)                   0.000000
#
#                                                account length_scaled  \
# LogisticRegression()                                        0.037798
# SVC(kernel='linear', probability=True)                      0.000011
# DecisionTreeClassifier()                                    0.019383
# LogisticRegression(C=9.1)                                   0.036196
# SVC(C=0.1, kernel='linear', probability=True)              -0.000004
# DecisionTreeClassifier(max_depth=5)                         0.000000
#
#                                                area code_scaled  \
# LogisticRegression()                                   0.076115
# SVC(kernel='linear', probability=True)                 0.000039
# DecisionTreeClassifier()                               0.002869
# LogisticRegression(C=9.1)                              0.076921
# SVC(C=0.1, kernel='linear', probability=True)          0.000002
# DecisionTreeClassifier(max_depth=5)                    0.000000
#
#                                                number vmail messages_scaled  \
# LogisticRegression()                                               0.111112
# SVC(kernel='linear', probability=True)                             0.000235
# DecisionTreeClassifier()                                           0.033160
# LogisticRegression(C=9.1)                                          0.290043
# SVC(C=0.1, kernel='linear', probability=True)                      0.000179
# DecisionTreeClassifier(max_depth=5)                                0.060009
#
#                                                total day minutes_scaled  \
# LogisticRegression()                                           0.317916
# SVC(kernel='linear', probability=True)                        -0.004013
# DecisionTreeClassifier()                                       0.149957
# LogisticRegression(C=9.1)                                      0.307528
# SVC(C=0.1, kernel='linear', probability=True)                 -0.000239
# DecisionTreeClassifier(max_depth=5)                            0.016315
#
#                                                total day calls_scaled  \
# LogisticRegression()                                        -0.002675
# SVC(kernel='linear', probability=True)                      -0.000034
# DecisionTreeClassifier()                                     0.025217
# LogisticRegression(C=9.1)                                   -0.004093
# SVC(C=0.1, kernel='linear', probability=True)               -0.000026
# DecisionTreeClassifier(max_depth=5)                          0.004826
#
#                                                total day charge_scaled  \
# LogisticRegression()                                          0.321106
# SVC(kernel='linear', probability=True)                        0.004157
# DecisionTreeClassifier()                                      0.115372
# LogisticRegression(C=9.1)                                     0.335873
# SVC(C=0.1, kernel='linear', probability=True)                 0.000369
# DecisionTreeClassifier(max_depth=5)                           0.288163
#
#                                                total eve minutes_scaled  \
# LogisticRegression()                                           0.179520
# SVC(kernel='linear', probability=True)                         0.007356
# DecisionTreeClassifier()                                       0.096784
# LogisticRegression(C=9.1)                                      0.240522
# SVC(C=0.1, kernel='linear', probability=True)                  0.001145
# DecisionTreeClassifier(max_depth=5)                            0.000000
#
#                                                total eve calls_scaled  \
# LogisticRegression()                                         0.030181
# SVC(kernel='linear', probability=True)                      -0.000019
# DecisionTreeClassifier()                                     0.021073
# LogisticRegression(C=9.1)                                    0.029598
# SVC(C=0.1, kernel='linear', probability=True)               -0.000053
# DecisionTreeClassifier(max_depth=5)                          0.000000
#
#                                                total eve charge_scaled  \
# LogisticRegression()                                          0.164689
# SVC(kernel='linear', probability=True)                       -0.007352
# DecisionTreeClassifier()                                      0.035581
# LogisticRegression(C=9.1)                                     0.107260
# SVC(C=0.1, kernel='linear', probability=True)                -0.001100
# DecisionTreeClassifier(max_depth=5)                           0.122278
#
#                                                total night minutes_scaled  \
# LogisticRegression()                                             0.086594
# SVC(kernel='linear', probability=True)                           0.015353
# DecisionTreeClassifier()                                         0.029874
# LogisticRegression(C=9.1)                                        0.166165
# SVC(C=0.1, kernel='linear', probability=True)                    0.001580
# DecisionTreeClassifier(max_depth=5)                              0.000000
#
#                                                total night calls_scaled  \
# LogisticRegression()                                           0.019816
# SVC(kernel='linear', probability=True)                        -0.000009
# DecisionTreeClassifier()                                       0.034309
# LogisticRegression(C=9.1)                                      0.020486
# SVC(C=0.1, kernel='linear', probability=True)                 -0.000025
# DecisionTreeClassifier(max_depth=5)                            0.010146
#
#                                                total night charge_scaled  \
# LogisticRegression()                                            0.067131
# SVC(kernel='linear', probability=True)                         -0.015333
# DecisionTreeClassifier()                                        0.031998
# LogisticRegression(C=9.1)                                      -0.009189
# SVC(C=0.1, kernel='linear', probability=True)                  -0.001476
# DecisionTreeClassifier(max_depth=5)                             0.017957
#
#                                                total intl minutes_scaled  \
# LogisticRegression()                                            0.129732
# SVC(kernel='linear', probability=True)                          0.002903
# DecisionTreeClassifier()                                        0.089943
# LogisticRegression(C=9.1)                                      -0.015903
# SVC(C=0.1, kernel='linear', probability=True)                   0.000320
# DecisionTreeClassifier(max_depth=5)                             0.123375
#
#                                                total intl calls_scaled  \
# LogisticRegression()                                         -0.244414
# SVC(kernel='linear', probability=True)                       -0.000079
# DecisionTreeClassifier()                                      0.072896
# LogisticRegression(C=9.1)                                    -0.248121
# SVC(C=0.1, kernel='linear', probability=True)                -0.000081
# DecisionTreeClassifier(max_depth=5)                           0.081500
#
#                                                total intl charge_scaled  \
# LogisticRegression()                                           0.164862
# SVC(kernel='linear', probability=True)                        -0.002772
# DecisionTreeClassifier()                                       0.010051
# LogisticRegression(C=9.1)                                      0.311967
# SVC(C=0.1, kernel='linear', probability=True)                 -0.000234
# DecisionTreeClassifier(max_depth=5)                            0.000000
#
#                                                customer service calls_scaled
# LogisticRegression()                                                0.650546
# SVC(kernel='linear', probability=True)                              0.000078
# DecisionTreeClassifier()                                            0.113570
# LogisticRegression(C=9.1)                                           0.656587
# SVC(C=0.1, kernel='linear', probability=True)                       0.000064
# DecisionTreeClassifier(max_depth=5)                                 0.158061

# %%
# ваш код здесь
features = x_train.columns
feature_imps = dict()
for model in models:
    try:
        feature_imps[str(model)] = model.feature_importances_[0]
    except AttributeError:
        feature_imps[str(model)] = model.coef_[0]
    finally:
        plt.figure(figsize=(4,4))
        plt.title(model)
        
        plt.barh(
        feature_imps_df.columns,
        feature_imps_df.loc[str(model)]
        )

# plt.legend(models, loc=(1,0))
    
        
        

#     
#     indices = np.argsort(importances)

#     plt.title('Feature Importances')
#         plt.barh(range(len(indices)), importances[indices], color='b', align='center')
#         plt.xticks(features)
#     plt.show()

# %%
# ваш код здесь
features = x_train.columns
feature_imps = dict()
for model in models:
    try:
        feature_imps[str(model)] = model.feature_importances_
       
    except AttributeError:
        feature_imps[str(model)] = model.coef_[0]
        
for key in feature_imps.keys():
    feature_imps[key] = list(abs(feature_imps[key]))
    
for key in feature_imps.keys():
    my_dict = dict()
    for i in range(len(feature_imps[key])):
        
        my_dict[x_train.columns[i]] = feature_imps[key][i] 
    feature_imps[key] = my_dict

# %%
most_important_features = dict()
for key in feature_imps.keys():
    first = None
    second = None
    third = None
    for feature in feature_imps[key].keys():
        
        if feature_imps[key][feature] == sorted(feature_imps[key].values())[-1]:
            first = feature
        if feature_imps[key][feature] == sorted(feature_imps[key].values())[-2]:
            second = feature
        if feature_imps[key][feature] == sorted(feature_imps[key].values())[-3]:
            third = feature
    most_important_features[key] = [
        first,
        second, 
        third,
    ]
    
# ваш код здесь
features = [
    'most important',
    'important too!',
    'well.. theres that too',
]

tst = list(features)

most_important_features_df = pd.DataFrame(columns=tst)

for model in most_important_features.keys():
    most_important_features_df.loc[model] = most_important_features[model]
most_important_features_df
# Out:
#                                                            most important  \
# LogisticRegression()                                   international plan
# SVC(kernel='linear', probability=True)         total night minutes_scaled
# DecisionTreeClassifier()                         total day minutes_scaled
# LogisticRegression(C=9.1)                              international plan
# SVC(C=0.1, kernel='linear', probability=True)  total night minutes_scaled
# DecisionTreeClassifier(max_depth=5)               total day charge_scaled
#
#                                                               important too!  \
# LogisticRegression()                                         voice mail plan
# SVC(kernel='linear', probability=True)             total night charge_scaled
# DecisionTreeClassifier()                             total day charge_scaled
# LogisticRegression(C=9.1)                                    voice mail plan
# SVC(C=0.1, kernel='linear', probability=True)      total night charge_scaled
# DecisionTreeClassifier(max_depth=5)            customer service calls_scaled
#
#                                                       well.. theres that too
# LogisticRegression()                           customer service calls_scaled
# SVC(kernel='linear', probability=True)              total eve minutes_scaled
# DecisionTreeClassifier()                       customer service calls_scaled
# LogisticRegression(C=9.1)                      customer service calls_scaled
# SVC(C=0.1, kernel='linear', probability=True)       total eve minutes_scaled
# DecisionTreeClassifier(max_depth=5)                total intl minutes_scaled

# %% [markdown]
# Сделайте выводы:
#
# 1. Являются ли данные сбалансированными? Что это означает?
#
# 2. Какая модель после подбора гиперпараметров лучше всего решает задачу с точки зрения метрики roc-auc?
#
# 3. Одинаковые ли признаки важны для работы двух наилучших моделей? Почему?

# %%
models
# Out:
# [LogisticRegression(),
#  SVC(kernel='linear', probability=True),
#  DecisionTreeClassifier(),
#  LogisticRegression(C=9.1),
#  SVC(C=0.1, kernel='linear', probability=True),
#  DecisionTreeClassifier(max_depth=5)]

# %% [markdown]
# 1) данные не сбалансированы  - "единичек" в 6 раз меньше нулей. предположительно это бы должно ухудшить качество модели, но все метрики вроде в порядке..

# %%
from sklearn.metrics import accuracy_score



acc_scores = dict()
acc_preds = dict()
    
for model in models:
    acc_preds[model] = model.predict(x_test)
    acc_scores[str(model)] = accuracy_score(y_test, acc_preds[model])
acc_scores
# Out:
# {'LogisticRegression()': 0.865,
#  "SVC(kernel='linear', probability=True)": 0.857,
#  'DecisionTreeClassifier()': 0.916,
#  'LogisticRegression(C=9.1)': 0.862,
#  "SVC(C=0.1, kernel='linear', probability=True)": 0.857,
#  'DecisionTreeClassifier(max_depth=5)': 0.935}

# %%
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score



rec_scores = dict()
rec_preds = dict()
    
for model in models:
    rec_preds[model] = model.predict(x_test)
    rec_scores[str(model)] = accuracy_score(y_test, rec_preds[model])
rec_scores



prc_scores = dict()
prc_preds = dict()
    
for model in models:
    prc_preds[str(model)] = model.predict(x_test)
    prc_scores[str(model)] = accuracy_score(y_test, prc_preds[str(model)])    
print('pricision')    
print(prc_scores)
print('recall')    
print(rec_scores)
# Out:
# pricision
# {'LogisticRegression()': 0.865, "SVC(kernel='linear', probability=True)": 0.857, 'DecisionTreeClassifier()': 0.916, 'LogisticRegression(C=9.1)': 0.862, "SVC(C=0.1, kernel='linear', probability=True)": 0.857, 'DecisionTreeClassifier(max_depth=5)': 0.935}
# recall
# {'LogisticRegression()': 0.865, "SVC(kernel='linear', probability=True)": 0.857, 'DecisionTreeClassifier()': 0.916, 'LogisticRegression(C=9.1)': 0.862, "SVC(C=0.1, kernel='linear', probability=True)": 0.857, 'DecisionTreeClassifier(max_depth=5)': 0.935}

# %%
from sklearn.metrics import confusion_matrix

for model in models:
#     acc_scores[str(model)] = accuracy_score(y_test, acc_preds[model])
    print(model)
    print(confusion_matrix(y_test, acc_preds[model]))
    print(acc_scores[str(model)])
    print('-'*3)
# Out:
# LogisticRegression()
# [[834  23]
#  [112  31]]
# 0.865
# ---
# SVC(kernel='linear', probability=True)
# [[857   0]
#  [143   0]]
# 0.857
# ---
# DecisionTreeClassifier()
# [[810  47]
#  [ 37 106]]
# 0.916
# ---
# LogisticRegression(C=9.1)
# [[832  25]
#  [113  30]]
# 0.862
# ---
# SVC(C=0.1, kernel='linear', probability=True)
# [[857   0]
#  [143   0]]
# 0.857
# ---
# DecisionTreeClassifier(max_depth=5)
# [[842  15]
#  [ 50  93]]
# 0.935
# ---

# %%
y_test.value_counts()
# Out:
# churn
# 0    857
# 1    143
# Name: count, dtype: int64

# %%
tst_svc = SVC(kernel='linear', probability=True)
tst_svc.fit(x_train, y_train)
svc_test_preds = tst_svc.predict_proba(x_test)[ : , 1 ]
counter = 0

# %%
counter = 0
for x in svc_test_preds > 0.67:
    if x == True:
        counter +=1 
counter
# Out:
# 0

# %% [markdown]
# в то же время явно видно, что модели гораздо лучше угадывают "нолики" - SVC в обоих ипостасиях не угадывает ни одной "единички" - что страннно, т.к. взглянув на вероятности с порогом 0,5 мы получим 6 единичек и лишь с порогом 0,67 единичек в предсказании быть не должно.

# %%
scores
# Out:
# {'LogisticRegression()': 0.8277125441652863,
#  "SVC(kernel='linear', probability=True)": 0.7557343473329472,
#  'DecisionTreeClassifier()': 0.8432081337565586,
#  'unscaled_DecisionTreeClassifier()': 0.8379613385447691,
#  'LogisticRegression(C=9.1)': 0.8283571737480723,
#  "SVC(C=0.1, kernel='linear', probability=True)": 0.7789818116539237,
#  'DecisionTreeClassifier(max_depth=5)': 0.9075364542108999}

# %% [markdown]
# 2. лучше всего справилось тюнингованное "дерево", причем не только по "року"

# %% [markdown]
# 3. оба дерева, показав лучшие результаты использовали одни и те же колонки, правда в оттюнингованной варианте веса этих признаков увеличились и немного перемешались - думаю это можно объяснить тем, что модель при тюнинге, как вы уже упоминали, не меняет свой принцип действие (минус замены "ядер", само собой), а потому и фичи, важные для этой модели остаются на месте. Если бы мы сравнивали две разные модели - фичи были бы разные, что можно проследить по df'у с важными колонками

# %%
most_important_features_df.loc[['DecisionTreeClassifier()', 'DecisionTreeClassifier(max_depth=5)']]
# Out:
#                                                most important  \
# DecisionTreeClassifier()             total day minutes_scaled
# DecisionTreeClassifier(max_depth=5)   total day charge_scaled
#
#                                                     important too!  \
# DecisionTreeClassifier()                   total day charge_scaled
# DecisionTreeClassifier(max_depth=5)  customer service calls_scaled
#
#                                             well.. theres that too
# DecisionTreeClassifier()             customer service calls_scaled
# DecisionTreeClassifier(max_depth=5)      total intl minutes_scaled

# %%
feature_imps['DecisionTreeClassifier()']
# Out:
# {'international plan': 0.07805542258405064,
#  'voice mail plan': 0.03990831098963623,
#  'account length_scaled': 0.019383158329098746,
#  'area code_scaled': 0.0028691105142508583,
#  'number vmail messages_scaled': 0.033159516562961414,
#  'total day minutes_scaled': 0.14995665781513676,
#  'total day calls_scaled': 0.02521663394110748,
#  'total day charge_scaled': 0.1153715809610345,
#  'total eve minutes_scaled': 0.09678365928794126,
#  'total eve calls_scaled': 0.021073175676743182,
#  'total eve charge_scaled': 0.035580839919083486,
#  'total night minutes_scaled': 0.02987419651722323,
#  'total night calls_scaled': 0.034309355696564285,
#  'total night charge_scaled': 0.031998447070842935,
#  'total intl minutes_scaled': 0.08994319851900791,
#  'total intl calls_scaled': 0.07289580218052982,
#  'total intl charge_scaled': 0.010051117372866188,
#  'customer service calls_scaled': 0.11356981606192107}

# %%
feature_imps['DecisionTreeClassifier(max_depth=5)']
# Out:
# {'international plan': 0.1173693999624844,
#  'voice mail plan': 0.0,
#  'account length_scaled': 0.0,
#  'area code_scaled': 0.0,
#  'number vmail messages_scaled': 0.06000882910250143,
#  'total day minutes_scaled': 0.016315475201362006,
#  'total day calls_scaled': 0.0048263748757102435,
#  'total day charge_scaled': 0.2881634746622049,
#  'total eve minutes_scaled': 0.0,
#  'total eve calls_scaled': 0.0,
#  'total eve charge_scaled': 0.12227766184139174,
#  'total night minutes_scaled': 0.0,
#  'total night calls_scaled': 0.010146206892112767,
#  'total night charge_scaled': 0.017956647329122073,
#  'total intl minutes_scaled': 0.12337477354821708,
#  'total intl calls_scaled': 0.08150042773062521,
#  'total intl charge_scaled': 0.0,
#  'customer service calls_scaled': 0.158060728854268}
